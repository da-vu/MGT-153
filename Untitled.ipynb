# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import xlwings as xw

# %%
path='Data.xlsx'

# %%
wb = xw.Book(path)

# %%
wb.sheets['console data'].activate()
wb.sheets['console data'].used_range.select()
console_df = xw.load(index=False,header=1)

# %%
console_df
# Out:
#                                    name platform  year_of_release     genre  \
# 0                           Weii Sports     Weii           2006.0    Sports
# 1                    Marrison Kart Weii     Weii           2008.0    Racing
# 2                    Weii Sports Resort     Weii           2009.0    Sports
# 3              New Super Marrison Bros.       DS           2006.0  Platform
# 4                             Weii Play     Weii           2006.0      Misc
# ...                                 ...      ...              ...       ...
# 8058     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 8059  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 8060                   Bust-A-Move 3000       GC           2003.0    Puzzle
# 8061                   Mega Brain Boost       DS           2008.0    Puzzle
# 8062            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
wb.sheets['population data'].activate()
wb.sheets['population data'].used_range.select()
population_df = xw.load(index=False,header=1)

# %%
population_df
# Out:
#            Country Name Country Code NA/EU/JP/Other        1995.0  \
# 0           Afghanistan          AFG          Other  1.709954e+07
# 1               Albania          ALB          Other  3.187784e+06
# 2               Algeria          DZA          Other  2.890430e+07
# 3        American Samoa          ASM          Other  5.286800e+04
# 4               Andorra          AND          Other  6.385000e+04
# ..                  ...          ...            ...           ...
# 259  West Bank and Gaza          PSE          Other  2.474666e+06
# 260               World          WLD          Other  5.713794e+09
# 261         Yemen, Rep.          YEM          Other  1.532065e+07
# 262              Zambia          ZMB          Other  9.137077e+06
# 263            Zimbabwe          ZWE          Other  1.132035e+07
#
#            1996.0        1997.0        1998.0        1999.0        2000.0  \
# 0    1.782288e+07  1.838160e+07  1.886400e+07  1.940368e+07  2.009376e+07
# ...

# %%
population_df[population_df['NA/EU/JP/Other']=='NA'][2006.0].sum()
# Out:
# 516818555.0

# %%
console_df['year_of_release']
# Out:
# 0       2006.0
# 1       2008.0
# 2       2009.0
# 3       2006.0
# 4       2006.0
#          ...
# 8058    2002.0
# 8059    2014.0
# 8060    2003.0
# 8061    2008.0
# 8062    2011.0
# Name: year_of_release, Length: 8063, dtype: float64

# %%
def get_na_pop(row):
    return population_df[population_df['NA/EU/JP/Other']=='NA'][row['year_of_release']].sum()

# %%
na_pop=console_df.apply(get_na_pop,axis=1)

# %%
wb.sheets['console data'].range('q2').options(index=False).value=na_pop

# %%
na_pop
# Out:
# 0       516818555.0
# 1       528816311.0
# 2       534740514.0
# 3       516818555.0
# 4       516818555.0
#            ...
# 8058    495013192.0
# 8059    562338430.0
# 8060    500125528.0
# 8061    528816311.0
# 8062    545961365.0
# Length: 8063, dtype: float64
