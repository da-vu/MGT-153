# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import xlwings as xw
from scipy import stats
import numpy as np

# %%
path='FILTERED CONSOLE.xlsx'

# %%
wb = xw.Book(path)

# %%
wb.sheets['filtered console'].activate()
wb.sheets['filtered console'].used_range.select()
console_df = xw.load(index=False,header=1)

# %%
console_df
# Out:
#                                    name platform  year_of_release     genre  \
# 0                           Weii Sports     Weii           2006.0    Sports
# 1                    Marrison Kart Weii     Weii           2008.0    Racing
# 2                    Weii Sports Resort     Weii           2009.0    Sports
# 3              New Super Marrison Bros.       DS           2006.0  Platform
# 4                             Weii Play     Weii           2006.0      Misc
# ...                                 ...      ...              ...       ...
# 5945                    Hospital Tycoon       PC           2007.0  Strategy
# 5946                   Fast Racing Neo     WeiiU           2016.0    Action
# 5947     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 5948  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 5949            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
rpg
# Out:
#                                             name platform  year_of_release  \
# 47                      7th Dragon III Code: VFD      3DS           2015.0
# 53                               Final Fantasy X      PS2           2001.0
# 55                     Pokí©mon Platinum Version       DS           2008.0
# 65                                A Witch's Tale       DS           2009.0
# 82                      Pokí©mon Emerald Version      GBA           2004.0
# ...                                          ...      ...              ...
# 5903                            The Technomancer       PC           2016.0
# 5918                   Marvel: Ultimate Alliance       PC           2006.0
# 5920                                     Deus Ex       PC           2000.0
# 5931  Dungeon Explorer: Warriors of Ancient Arts      PSP           2007.0
# 5934         Hoshigami: Ruining Blue Earth Remix       DS           2007.0
#
# ...

# %%
rpg=console_df[console_df['genre']=='Role-Playing']

# %%
sns.histplot(data=rpg,x='total sales')
# Out:
# <AxesSubplot:xlabel='total sales', ylabel='Count'>

# %%
rpg['total sales'].mean(),rpg['total sales'].median(),rpg['total sales'].std()
# Out:
# (769049.2957746478, 315000.0, 1240442.8908526474)

# %%
filtered_rpg=rpg[rpg['year_of_release']>=2011]

# %%
xw.view(filtered_rpg)
